# %% [markdown]
# ### Load Data

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# selected 2 columns sepal length and sepal width
X = X[:,:2]

# %% [markdown]
# ### Building Model

# %%
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt

# %%
svc = svm.SVC().fit(X, y)
svc
# Out:
# C:\Users\Mangesh Karande\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
# Default values are: C=1.0 , kernel='rbf' , decision_function_shape='ovr' > means "one-verses-rest"

# %%
svc = svm.SVC(C=0.01, kernel='linear').fit(X, y)

# %%
def plot_boundary(svc):
    
    # create a mesh to plot in
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    h = (x_max / x_min)/100
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    plt.subplot(1, 1, 1)
    Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.7)

    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    plt.xlim(xx.min(), xx.max())
    #plt.title('SVC with linear kernel')
    plt.show()

# %%
plot_boundary(svc)

# %% [markdown]
# Try different values of C

# %%
svc = svm.SVC(C=1, kernel='linear').fit(X,y)
plot_boundary(svc)

# %% [markdown]
# Using RBF Kernel

# %%
svc = svm.SVC(C=1, kernel='rbf', gamma=1).fit(X,y)
plot_boundary(svc)

# %%
svc = svm.SVC(C=1, kernel='poly', degree=3, gamma=1).fit(X,y)
plot_boundary(svc)

# %%
# For degree=2
svc = svm.SVC(C=1, kernel='poly', degree=2, gamma=1).fit(X,y)
plot_boundary(svc)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
X = data_complete.drop("left", axis=1)
y = data_complete["left"]
test_size = 0.30 # taking 70:30 training and test set
seed = 7  # Random numbmer seeding for reapeatability of the code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a62e9e5aafbc> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
#       2 clf = svm.SVC(C=10)
#
# NameError: name 'test_size' is not defined

# %%
clf.fit(X_train , y_train)

# %%
clf.score(X_train, y_train)

# %%
clf.score(X_test, y_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
model.score(X_train, y_train)

# %%
model.score(X_test, y_test)
